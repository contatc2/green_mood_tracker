# %%
import sys
sys.path.insert(0, '../green_mood_tracker/')
sys.path.insert(0, '../raw_data/')
import pandas as pd

# %%
! ls ../green_mood_tracker/
# Out:
# __init__.py      data             lib.py           twint_class.py
# __pycache__      data_cleaning.py training_data.py

# %%
from training_data import get_raw_data_notebook

# %%
data = get_raw_data_notebook()
# Out:
# ../green_mood_tracker/training_data.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sentiment140_final['source'] = 'sentiment140'

# %%
data.shape
# Out:
# (1633048, 4)

# %%
data.to_csv('../raw_data/final.csv', index=False)

# %%
df = pd.read_csv('../raw_data/final.csv')
df.shape
# Out:
# /Users/leonardogavaudan/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (1633048, 4)

# %%
df
# Out:
#                  id                                               text  \
# 0        1467933112  the angel is going to miss the athlete this we...
# 1        2323395086  It looks as though Shaq is getting traded to C...
# 2        1467968979     @clarianne APRIL 9TH ISN'T COMING SOON ENOUGH
# 3        1990283756  drinking a McDonalds coffee and not understand...
# 4        1988884918  So dissapointed Taylor Swift doesnt have a Twi...
# 5        1467984364  Wishes I was on the Spring Fling Tour with Daw...
# 6        1964951623  got a sniffle, got the kids and hubby just lef...
# 7        1881133744  i've only been in sydney for 3 hrs but I miss ...
# 8        1753802024                       xboxtweet not working again
# 9        1980497384        R.I.P to lebron/kobe puppet commercials...
# 10       1755405128  Allergies sucks sometimes. Theres a super ador...
# 11       1966205498                               has a broken iphone
# ...
