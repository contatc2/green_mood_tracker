# %%
import nest_asyncio
import twint
import sys
import pandas as pd
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import download
download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/leonardogavaudan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nest_asyncio.apply()

# %load_ext autoreload
# %autoreload 2

sys.path.insert(0, '../green_mood_tracker/')
from twint_class import TWINT
from data_cleaning import clean
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !ls
# Out:
# Untitled.ipynb   twint-test.ipynb

# %%
# !pwd
# Out:
# /Users/leonardogavaudan/code/leonardogavaudan/green_mood_tracker/notebooks

# %%
df = pd.read_csv('../green_mood_tracker/data/sts_gold_tweet.csv', sep=';')
df.head()
# Out:
#            id  polarity                                              tweet
# 0  1467933112         0  the angel is going to miss the athlete this we...
# 1  2323395086         0  It looks as though Shaq is getting traded to C...
# 2  1467968979         0     @clarianne APRIL 9TH ISN'T COMING SOON ENOUGH
# 3  1990283756         0  drinking a McDonalds coffee and not understand...
# 4  1988884918         0  So dissapointed Taylor Swift doesnt have a Twi...

# %%
clean(df, column='tweet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/leonardogavaudan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#               id  polarity                                              tweet
# 0     1467933112         0                   angel going miss athlete weekend
# 1     2323395086         0  look though shaq getting traded cleveland play...
# 2     1467968979         0         clarianne april th isnt coming soon enough
# 3     1990283756         0  drinking mcdonalds coffee understanding someon...
# 4     1988884918         0           dissapointed taylor swift doesnt twitter
# 5     1467984364         0  wish wa spring fling tour dawn amp neecee sigh...
# 6     1964951623         0  got sniffle got kid hubby left work sydney wee...
# 7     1881133744         0        ive sydney hr miss friend especially ktjade
# 8     1753802024         0                                  xboxtweet working
# 9     1980497384         0                   rip lebronkobe puppet commercial
# 10    1755405128         0  allergy suck sometimes super adorable month ol...
# 11    1966205498         0                                   ha broken iphone
# 12    2206224118         0    line mcdonalds wa long cant get sausage biscuit
# 13    1687790990         0  stephnewby virus going around congestion throw...
# 14    1963812485         0                                     scratched ipod
# 15    1467844505         0                        dont understand really dont
# 16    2258491381         0  rove pink hero love wanna go see brisvegas sad...
# 17    1468039375         0          hate fact im genuinely excited last tweet
# 18    2212063772         0  tulas sick nausious nasal congestion headache ...
# 19    1557163971         0                                 hayfever time good
# 20    1975133437         0  wish diversity wa like one musician load stuff...
# 21    1932575931         0  oh cavs lost game cavs loss away triggering nu...
# 22    1467899025         0  still sick feeling bit better got new medicine...
# 23    2324113552         0               worked bone marrow case today cancer
# 24    1468042132         0                                 wa sleepless night
# 25    1467985185         0                  dcastillo ugh thats disconcerting
# 26    1980282216         0  forgot english coursework amp ipod banjaxed to...
# 27    2179698078         0                            tweetramona bad seattle
# 28    1467985259         0                                  tweet arent going
# 29    2299794306         0      seattlerealest calorie gram fat carbs mexifry
# ...          ...       ...                                                ...
# 2004  2194433506         0  im tweetless without miphone cant wait new one...
# 2005  1978986441         0   seeing ronans latest update wish wa london right
# 2006  1467912100         0  carolrainbow internet home drive ox use intern...
# 2007  1467872759         0           im lonely keep company female california
# 2008  1932409653         0                    damn cavs lost lost sum chippaz
# 2009  1982476349         0  cant finish damn homework fifty question go wa...
# 2010  1467858627         0  woke already written email ive go early univer...
# 2011  2199414669         0                          got fever aint disco kind
# 2012  2013743788         0  leehopkins ok guy adorable given u notice coul...
# 2013  2241033723         0  really want iphone pay thing first dang respon...
# 2014  1795305046         0  michelletripp dont bummed saw imax sydney larg...
# 2015  1467910986         0          keeping finger crossed buddy feeling well
# 2016  1468038099         0      sudam yes someone hasnt reading post properly
# 2017  2053385413         0               miss much sosososo much wanna sydney
# 2018  2000663077         0  waking feeling really tired doe hayfever exist...
# 2019  1467879203         0  saw found tracy girl piece luggage fucking ter...
# 2020  2057515232         0                watching uruguaybrazil need miracle
# 2021  1754305167         0  kevinprince couldnt buy openhacklondon cant ev...
# 2022  2209465938         0  simondoggett would like install iphone phone i...
# 2023  1880171965         0          realised hueyyei psp bag cant play though
# 2024  2214025188         0  hope microsoft fixed xboxlive marketplace morn...
# 2025  1467986976         0  georgeruiz unfortunately one moment wasnt gian...
# 2026  1752634162         0  bleumuze hit gameworks movie downtown seattle ...
# 2027  1467871661         0  miss twitter phone broke im using stupid nokia...
# 2028  2071726448         0  ilovelyci lol said cavs deserve final thanks b...
# 2029  1468049681         0  king sized bed nice sad lonely hubby puppy kit...
# 2030  2195475499         0         breannalovesjb hurry home im dying youtube
# 2031  1996172176         0  jordanhowell lol psp game boy cousin lost amp ...
# 2032  2016105580         4    good morning everyone beautiful day new england
# 2033  2186977170         4  hey guess wa magicmanil lakers kobe mvp though...
#
# [2034 rows x 3 columns]
