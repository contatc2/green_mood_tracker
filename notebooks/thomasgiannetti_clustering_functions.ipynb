# %%
import sys
sys.path.insert(0, '../green_mood_tracker/')
from twint_class import TWINT
from training_data import get_raw_data_notebook
import nest_asyncio
import twint
import pandas as pd

nest_asyncio.apply()

# %load_ext autoreload
# %autoreload 2
import nest_asyncio
import twint
import pandas as pd

nest_asyncio.apply()

# %load_ext autoreload
# %autoreload 2

from data_cleaning import clean
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/thomasgiannetti/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
kwargs = dict(
    keywords=['solar energy'],
    cities=['London', 'Paris'],
    since = '2020-11-08 12:00:00',
    store_csv=False,
    limit=500
)

t = TWINT(**kwargs)

df_city = t.city_df()
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
df_city[['tweet']].head()
# Out:
#                                                tweet
# 0  Another amazing day of content and networking ...
# 1  Time is running out to get 20% off all tickets...
# 2  Solar energy is the term used to describe the ...
# 3  Here it is, the last #LSSEU20 session!   CASE ...
# 4  We can all make the #world a better place in o...

# %%
df_city['tweet'] = df_city['tweet'].str.replace(kwargs['keywords'][0], '')

# %%
from clustering import plotWords
plotWords(df_city, 'tweet', 10)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    5.7s finished
# /Users/thomasgiannetti/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_search.py:842: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=-1)]: Done 285 out of 285 | elapsed:   55.3s finished
# /Users/thomasgiannetti/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_search.py:842: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
from clustering import generateWordClouds
generateWordClouds(df_city, 'tweet', 10)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    8.5s finished
# /Users/thomasgiannetti/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_search.py:842: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:   42.3s
# [Parallel(n_jobs=-1)]: Done 285 out of 285 | elapsed:   52.0s finished
# /Users/thomasgiannetti/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_search.py:842: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    7.4s finished
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:   40.3s
# [Parallel(n_jobs=-1)]: Done 285 out of 285 | elapsed:   52.8s finished
# /Users/thomasgiannetti/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_search.py:842: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
